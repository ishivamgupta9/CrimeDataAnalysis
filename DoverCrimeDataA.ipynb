# %% [markdown]
# <a href="https://colab.research.google.com/github/ishivamgupta9/CrimeDataAnalysis/blob/main/DoverCrimeDataA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace YOUR_FILE_ID with the actual file ID (the part after 'd/' and before '/view')
file_id = "14T2qBpIuv8rYxq7AFJTYStGtkzt5RTe1"
file_url = f"https://drive.google.com/uc?id={file_id}"

data= pd.read_csv(file_url)

data
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 165  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 166                              LARCENY / SHOPLIFTING
# 167                            LARCENY / FROM BUILDING
# 168  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 169                     LARCENY / FROM ALL OTHER YARDS
#
#                         Location        Agency                Date
# 0       200 BLOCK N SAULSBURY RD  Dover Police   9/25/2023 2:55 AM
# 1       100 BLOCK\nLOOCKERMAN ST  Dover Police   9/25/2023 1:07 AM
# 2        800 BLOCK N MONROE\nTER  Dover Police  9/24/2023 12:26 AM
# ...

# %%
import pandas as pd
import requests

df = pd.DataFrame(data)
df["Location"]=df["Location"]+", Dover, DE, USA"

# Define your Google Maps API key and the base URL
API_KEY = ""
BASE_URL = "https://maps.googleapis.com/maps/api/geocode/json"

# Function to geocode a location
def geocode_location(location):
    try:
        # Include the API URL and key in the request
        url = f"{BASE_URL}?address={location}&key={API_KEY}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if data["status"] == "OK":
                location = data["results"][0]["geometry"]["location"]
                latitude = location["lat"]
                longitude = location["lng"]
                return latitude, longitude
    except Exception as e:
        print(f"Geocoding error: {str(e)}")
    return None, None

# Apply geocoding to the "Location" column
df["Latitude"], df["Longitude"] = zip(*df["Location"].apply(geocode_location))

# Display the updated DataFrame
df
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 165  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 166                              LARCENY / SHOPLIFTING
# 167                            LARCENY / FROM BUILDING
# 168  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 169                     LARCENY / FROM ALL OTHER YARDS
#
#                                         Location        Agency  \
# 0       200 BLOCK N SAULSBURY RD, Dover, DE, USA  Dover Police
# 1       100 BLOCK\nLOOCKERMAN ST, Dover, DE, USA  Dover Police
# 2        800 BLOCK N MONROE\nTER, Dover, DE, USA  Dover Police
# ...

# %%
df.to_csv("DoverCrimewithGeo.csv")

# %%
import pandas as pd

# Replace YOUR_FILE_ID with the actual file ID (the part after 'd/' and before '/view')
# file_id = "1_GfRuOWFeK0xs92JUH16HJ-VBvxKirat"

file_id = "1aQiwMp8pdfmy3ztd_xcCFNI8aF6jIMRL"
file_url = f"https://drive.google.com/uc?id={file_id}"

cd = pd.read_csv(file_url)
cd
# Out:
#      Unnamed: 0                                        Description  \
# 0             0                              LARCENY / SHOPLIFTING
# 1             1  SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2             2  OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3             3  OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4             4                            LARCENY / FROM BUILDING
# ..          ...                                                ...
# 165         165  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 166         166                              LARCENY / SHOPLIFTING
# 167         167                            LARCENY / FROM BUILDING
# 168         168  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 169         169                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# ...

# %%
cd=cd.drop("Unnamed: 0",axis=1)

# %%
cd
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 165  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 166                              LARCENY / SHOPLIFTING
# 167                            LARCENY / FROM BUILDING
# 168  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 169                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# 1    100 BLOCK\nLOOCKERMAN ST,Dover,DE,USA, Dover, ...  Dover Police
# 2    800 BLOCK N MONROE\nTER,Dover,DE,USA, Dover, D...  Dover Police
# ...

# %%
cd=cd.dropna(subset=["Latitude","Longitude"])

# %%
cd.isna().any()
# Out:
# Description     True
# Location       False
# Agency          True
# Date            True
# Latitude       False
# Longitude      False
# dtype: bool

# %%
rows_with_null = cd[cd.isna().any(axis=1)]
rows_with_null
# Out:
#    Description                                           Location Agency Date  \
# 68         NaN  BRADFORD ST,Dover,DE,USA, Dover, DE, USA, Dove...    NaN  NaN
#
#      Latitude  Longitude
# 68  39.143044 -75.524281

# %%
cd=cd.dropna()

# %%
cd.shape
# Out:
# (163, 6)

# %%
cd.isna().any()
# Out:
# Description    False
# Location       False
# Agency         False
# Date           False
# Latitude       False
# Longitude      False
# dtype: bool

# %%
import pandas as pd
import requests

df = pd.DataFrame(cd).head(1)

# Define your Google Maps API key and the base URL
API_KEY = ""
BASE_URL = "https://maps.googleapis.com/maps/api/geocode/json"

# Function to geocode a location and extract the postal code (zip code)
def geocode_location(location):
    try:
        # Include the API URL and key in the request
        url = f"{BASE_URL}?address={location}&key={API_KEY}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if data["status"] == "OK":
                # Initialize the zip code variable
                zip_code = None

                # Loop through the address components to find the postal code
                for result in data["results"]:
                    for component in result["address_components"]:
                        if "postal_code" in component["types"]:
                            zip_code = component["short_name"]
                            break
                    if zip_code is not None:
                        return zip_code
    except Exception as e:
        print(f"Geocoding error: {str(e)}")
    return None

# Apply geocoding to the "Location" column and create a new "Zip Code" column
df["Zip Code"] = df["Location"].apply(geocode_location)

df
# Display the updated DataFrame
# Out:
#              Description                                           Location  \
# 0  LARCENY / SHOPLIFTING  200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...
#
#          Agency               Date   Latitude  Longitude Zip Code
# 0  Dover Police  9/25/2023 2:55 AM  39.163263 -75.545224     None

# %%
# import pandas as pd
# import requests

# df= pd.DataFrame(cd).head(5)

# # Define your Google Maps API key and the base URL
# API_KEY = "AIzaSyApK1AGbSIVoPlNPdtclBbY1ZjEQ8vyU20"
# BASE_URL = "https://maps.googleapis.com/maps/api/geocode/json"

# # # Function to geocode a location and extract the postal code (zip code)
# # def geocode_location(location):
# #     try:
# #         # Include the API URL and key in the request
# #         url = f"{BASE_URL}?address={location}&key={API_KEY}"
# #         response = requests.get(url)
# #         if response.status_code == 200:
# #             data = response.json()
# #             if data["status"] == "OK":
# #                 # Initialize the zip code variable
# #                 zip_code = None

# #                 # Loop through the address components to find the postal code
# #                 for result in data["results"]:
# #                     for component in result["address_components"]:
# #                         if "neighborhood" in component["types"]:
# #                             neighborhood = component["long_name"]
# #                             break

# #     except Exception as e:
# #         print(f"Geocoding error: {str(e)}")
# #     return None

# # # Apply geocoding to the "Location" column and create a new "Zip Code" column
# # df["neighborhood"] = df["Location"].apply(geocode_location)

# # df



# # Function to geocode a location and extract the neighborhood
# def geocode_location(location):
#     try:
#         # Include the API URL and key in the request
#         url = f"{BASE_URL}?address={location}&key={API_KEY}"
#         response = requests.get(url)
#         if response.status_code == 200:
#             data = response.json()
#             if data["status"] == "OK":
#                 # Initialize the neighborhood variable
#                 neighborhood = None

#                 # Loop through the address components to find the neighborhood
#                 for result in data["results"]:
#                     for component in result["address_components"]:
#                         if "neighborhood" in component.get("types", []):
#                             neighborhood = component["long_name"]
#                             break

#                 return neighborhood

#     except Exception as e:
#         print(f"Geocoding error: {str(e)}")
#     return None

# # Apply geocoding to the "Location" column and create a new "Neighborhood" column
# df["Neighborhood"] = df["Location"].apply(geocode_location)

# df

# %%
df["Zip Code"].isna()
# Out:
# 0    True
# Name: Zip Code, dtype: bool

# %%
rows_with_null = df[df.isna().any(axis=1)]
rows_with_null
# Out:
#              Description                                           Location  \
# 0  LARCENY / SHOPLIFTING  200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...
#
#          Agency               Date   Latitude  Longitude Zip Code
# 0  Dover Police  9/25/2023 2:55 AM  39.163263 -75.545224     None

# %%
df=df.dropna(subset=["Zip Code"])
df
# Out:
# Empty DataFrame
# Columns: [Description, Location, Agency, Date, Latitude, Longitude, Zip Code]
# Index: []

# %%
df.to_csv("DoverCrimeCleanedwithZIP.csv")

# %%
file_id = "1rTeEKgHLD-yOfnBjOwljonwtXo1DfNjU"
file_url = f"https://drive.google.com/uc?id={file_id}"

crimedata= pd.read_csv(file_url)

crimedata
# Out:
#      Unnamed: 0                                        Description  \
# 0             0                              LARCENY / SHOPLIFTING
# 1             1  SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2             2  OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3             3  OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4             4                            LARCENY / FROM BUILDING
# ..          ...                                                ...
# 156         165  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 157         166                              LARCENY / SHOPLIFTING
# 158         167                            LARCENY / FROM BUILDING
# 159         168  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 160         169                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# ...

# %%
crimedata=crimedata.drop("Unnamed: 0",axis=1)

# %%
crimedata
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 156  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 157                              LARCENY / SHOPLIFTING
# 158                            LARCENY / FROM BUILDING
# 159  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 160                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# 1    100 BLOCK\nLOOCKERMAN ST,Dover,DE,USA, Dover, ...  Dover Police
# 2    800 BLOCK N MONROE\nTER,Dover,DE,USA, Dover, D...  Dover Police
# ...

# %%
zipcode_incident_total=crimedata.groupby('Zip Code')['Description'].count()
zipcode_incident_total
# Out:
# Zip Code
# 2180       1
# 19720      2
# 19901     71
# 19904     84
# 89509      1
# 535700     2
# Name: Description, dtype: int64

# %%
zip_to_remove = [2180, 89509, 535700]
crimedata = crimedata[~crimedata['Zip Code'].isin(zip_to_remove)]
zipcode_incident_total=crimedata.groupby('Zip Code')['Description'].count()
zipcode_incident_total
# Out:
# Zip Code
# 19720     2
# 19901    71
# 19904    84
# Name: Description, dtype: int64

# %%
zipcode_incident_total=crimedata.groupby('Zip Code')['Description'].count().reset_index()

zipcode_incident_total.columns = ['Zip Code', 'Crime Count']

# Print the result
print(zipcode_incident_total)
# Out:
#    Zip Code  Crime Count
# 0     19720            2
# 1     19901           71
# 2     19904           84

# %%
crime_frequency = crimedata['Description'].value_counts()


crime_frequency
# Out:
# LARCENY / SHOPLIFTING                                                                                     38
# LARCENY / FROM BUILDING                                                                                   27
# OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGGRAVATED                                                     14
# DAMAGE / PRIVATE PROPERTY                                                                                  8
# INTIMIDATION / RECKLESS ENDANGER / TERRORISTIC\nTHREAT / HARASSMENT / OTHER ASSAULTS / NON\nAGGRAVATED     7
# AGGRAVATED ASSAULT / NON - FAMILY FIREARM                                                                  6
# LARCENY / FROM VEHICLE / NOT ATTACHED                                                                      6
# DAMAGE / BUSINESS PROPERTY                                                                                 4
# POSSESSION OF WEAPON                                                                                       3
# ...

# %%
#pivot table for crime by months or timeline

# %%
crimedata['crimedatatime']=pd.to_datetime(crimedata['Date'])
crimedata['Month']=crimedata['crimedatatime'].dt.strftime('%B')

crimedata
# Out:
# <ipython-input-96-02c355e9a2e7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-96-02c355e9a2e7>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# ...

# %%
crime_by_month = crimedata.groupby(['Month', 'Description']).size().unstack(fill_value=0)
crime_by_month
# Out:
# Description  AGGRAVATED ASSAULT / NON - FAMILY FIREARM  \
# Month
# April                                                3
# August                                               0
# July                                                 1
# June                                                 0
# May                                                  0
# September                                            2
#
# Description  AGGRAVATED ASSAULT / NON - FAMILY KNIFE / CUTTING\nINSTRUMENT  \
# Month
# April                                                        1
# August                                                       0
# July                                                         0
# June                                                         0
# May                                                          0
# September                                                    0
#
# Description  AGGRAVATED ASSAULT / NON - FAMILY OTHER\nDANGEROUS WEAPON  \
# Month
# ...

# %%
import matplotlib.pyplot as plt
crime_by_month = crimedata.groupby(['Month', 'Description']).size().unstack(fill_value=0)

# Plotting
crime_by_month.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Crime Frequency by Month')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.legend(title='Crime Description', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
crime_by_month = crimedata.groupby(['Month', 'Description']).size().unstack(fill_value=0)

# Plotting
crime_by_month.plot(kind='line', figsize=(12, 6))
plt.title('Crime Frequency by Month')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.legend(title='Crime Description', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#zipcode and crime frequency.

crimedata.groupby(["Zip Code"])["Description"].count()
# Out:
# Zip Code
# 19720     2
# 19901    71
# 19904    84
# Name: Description, dtype: int64

# %%
crimedata["Total Incident"]=1
# Out:
# <ipython-input-101-2d84a7147147>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
crimedata
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 156  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 157                              LARCENY / SHOPLIFTING
# 158                            LARCENY / FROM BUILDING
# 159  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 160                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# 1    100 BLOCK\nLOOCKERMAN ST,Dover,DE,USA, Dover, ...  Dover Police
# 2    800 BLOCK N MONROE\nTER,Dover,DE,USA, Dover, D...  Dover Police
# ...

# %%
ZipCode_incident_totals = crimedata.groupby('Zip Code')['Total Incident'].sum().reset_index()

# Define thresholds for high, moderate, and low incident neighborhoods
high_incident_threshold = 75
moderate_incident_threshold =70

# Create a new column 'Incident Level' based on total incidents
def categorize_neighborhood(total_incidents):
    if total_incidents >= high_incident_threshold:
        return 'High Incidents'
    elif total_incidents >= moderate_incident_threshold:
        return 'Moderate Incidents'
    else:
        return 'Low Incidents'

ZipCode_incident_totals['Incident Level'] =ZipCode_incident_totals ['Total Incident'].apply(categorize_neighborhood)
# crimedata['Crime Level'] = crimedata['Total Incident'].apply(categorize_neighborhood)

# Explore the neighborhoods with their respective incident levels
ZipCode_incident_totals
# Out:
#    Zip Code  Total Incident      Incident Level
# 0     19720               2       Low Incidents
# 1     19901              71  Moderate Incidents
# 2     19904              84      High Incidents

# %%
crimedata
# Out:
#                                            Description  \
# 0                                LARCENY / SHOPLIFTING
# 1    SIMPLE ASSAULT / NON - FAMILY / OTHER\nASSAULT...
# 2    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 3    OFFENSIVE TOUCHING / OTHER ASSAULTS / NON\nAGG...
# 4                              LARCENY / FROM BUILDING
# ..                                                 ...
# 156  HARASSING COMMUNICATION / PHONE / WIRE / MAIL\...
# 157                              LARCENY / SHOPLIFTING
# 158                            LARCENY / FROM BUILDING
# 159  SIMPLE ASSAULT / POLICE OFFICER / OTHER\nASSAU...
# 160                     LARCENY / FROM ALL OTHER YARDS
#
#                                               Location        Agency  \
# 0    200 BLOCK N SAULSBURY RD,Dover,DE,USA, Dover, ...  Dover Police
# 1    100 BLOCK\nLOOCKERMAN ST,Dover,DE,USA, Dover, ...  Dover Police
# 2    800 BLOCK N MONROE\nTER,Dover,DE,USA, Dover, D...  Dover Police
# ...

# %%
# low_incidents = crimedata[crimedata['Crime Level'] == 'Low Incidents']
# moderate_incidents = crimedata[crimedata['Crime Level'] == 'Moderate Incidents']
# high_incidents = crimedata[crimedata['Crime Level'] == 'High Incidents']

# %% [markdown]
# ### **School** **Data**

# %%
file_id="1wYcRdNlpAZBsY29m6zOj2566-Y9y5VGR";
file_url = f"https://drive.google.com/uc?id={file_id}"

schooldata= pd.read_csv(file_url)
schooldata
# Out:
#                                                  Name  GreatSchools Rating  \
# 0                     Frear (Allen) Elementary School                    9
# 1                  Dover Air Force Base Middle School                    9
# 2           Welch (Major George S.) Elementary School                    8
# 3                         Star Hill Elementary School                    7
# 4                    Simpson (W.B.) Elementary School                    7
# 5   Early College High School at Delaware State Un...                    6
# 6                           Caesar Rodney High School                    6
# 7                       North Dover Elementary School                    6
# 8                             Campus Community School                    6
# 9              Booker T. Washington Elementary School                    5
# 10           Stokes (Nellie Hughes) Elementary School                    4
# ...

# %%
import pandas as pd
import requests

df = pd.DataFrame(schooldata)


# Define your Google Maps API key and the base URL
API_KEY = "AIzaSyApK1AGbSIVoPlNPdtclBbY1ZjEQ8vyU20"
BASE_URL = "https://maps.googleapis.com/maps/api/geocode/json"

# Function to geocode a location
def geocode_location(location):
    try:
        # Include the API URL and key in the request
        url = f"{BASE_URL}?address={location}&key={API_KEY}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if data["status"] == "OK":
                location = data["results"][0]["geometry"]["location"]
                latitude = location["lat"]
                longitude = location["lng"]
                return latitude, longitude
    except Exception as e:
        print(f"Geocoding error: {str(e)}")
    return None, None

# Apply geocoding to the "Location" column
df["Latitude"], df["Longitude"] = zip(*df["Address"].apply(geocode_location))

# Display the updated DataFrame
df
# Out:
#                                                  Name  GreatSchools Rating  \
# 0                     Frear (Allen) Elementary School                    9
# 1                  Dover Air Force Base Middle School                    9
# 2           Welch (Major George S.) Elementary School                    8
# 3                         Star Hill Elementary School                    7
# 4                    Simpson (W.B.) Elementary School                    7
# 5   Early College High School at Delaware State Un...                    6
# 6                           Caesar Rodney High School                    6
# 7                       North Dover Elementary School                    6
# 8                             Campus Community School                    6
# 9              Booker T. Washington Elementary School                    5
# 10           Stokes (Nellie Hughes) Elementary School                    4
# ...

# %%
#HEAP MAP WHICH SHOWS CRIME DATA ONLY

import plotly.express as px
import plotly.graph_objects as go

fig = px.density_mapbox(crimedata, lat='Latitude', lon='Longitude', radius=10, zoom=10)
#fig.update_layout(mapbox_style="carto-positron", mapbox_center={"lat": 39.163263, "lon": -75.52})


fig.update_layout(
    mapbox_style="carto-positron",
    mapbox_center={"lat": 39.163263, "lon": -75.52},
    margin={"r": 0, "t": 0, "l": 0, "b": 0}
)


# Display the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#HEAP MAP WHICH SHOWS CRIME DATA AND SCHOOL DATA TOGETHER

import plotly.graph_objects as go

# Create a scattermapbox for crime data
crime_trace = go.Scattermapbox(
    lat=crimedata['Latitude'],
    lon=crimedata['Longitude'],
    mode='markers',
    marker=dict(size=10, color='red'),
    name='Crime Data'

)

# Create a scattermapbox for school data
school_trace = go.Scattermapbox(
    lat=schooldata['Latitude'],
    lon=schooldata['Longitude'],
    mode='markers',
    marker=dict(size=10, color='blue'),
    name='School Data'
)

# Create the layout for the map
layout = go.Layout(
    mapbox_style="carto-positron",
    mapbox_center={"lat": 39.163263, "lon": -75.52},
    mapbox=dict(
        center={"lat": 39.163263, "lon": -75.52},
        zoom=10
    ),
    margin={"r": 0, "t": 0, "l": 0, "b": 0},
    legend=dict(orientation="h", x=0, y=1.02)
)

# Create a figure with both traces
fig = go.Figure(data=[crime_trace, school_trace], layout=layout)

# Display the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crimedata['Description']

# %%
import folium
import pandas as pd

# Sample crime data (replace with your data)
data = pd.DataFrame({
    'Latitude': [39.163263, 39.157874, 39.148747],  # Add your latitude values
    'Longitude': [-75.545224, -75.525731, -75.526298],  # Add your longitude values
    'Incident Level': ['Low Incidents', 'Moderate Incidents', 'High Incidents']  # Add your incident levels
})

m = folium.Map(location=[39.163263, -75.545224], zoom_start=12)  # Adjust the initial map location and zoom level

# Define colors for red, yellow, and green zones
colors = {
    'Low Incidents': 'green',
    'Moderate Incidents': 'yellow',
    'High Incidents': 'red',
}

# Add markers to the map based on the incident level
for _, row in data.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color=colors[row['Incident Level']],
        fill=True,
        fill_color=colors[row['Incident Level']],
    ).add_to(m)

m.save('crime_heatmap.html')  # Save the map as an HTML file

# %%
import plotly.express as px
fig = px.choropleth(crimedata,
                    # locations='state_code',
                    locationmode="USA-states",
                    scope="usa",
                    color='Description',
                    color_continuous_scale="Viridis_r",

                    )


fig.update_layout(
      title_text = 'Jan 2022 Median Housing Price by State',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black",
      title_x=0.45,
         )


fig.show()

# %%
# import plotly.express as px

# fig = px.choropleth(crimedata,
#                     locations='Zip Code',  # Column in your DataFrame with ZIP codes
#                     color='Crime Level',  # Column in your DataFrame that determines the color (red/yellow/green zones)
#                     color_discrete_map={'Low Incidents': 'green', 'Moderate Incidents': 'yellow', 'High Incidents': 'red'},
#                     locationmode="USA-zip",
#                     scope="usa",
#                     hover_name='Description'  # Hover over ZIP codes to display crime descriptions
#                     )

# fig.update_geos(fitbounds="locations", visible=False)  # Fit the map to the locations
# fig.show()
